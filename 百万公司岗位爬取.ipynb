# %%
import requests
import urllib.request as r
import re
import lxml
from lxml.etree import HTML
from wget import download

# %%
for i in range (1,2):
    try:
        f=open('企业网页.txt','a',encoding='gbk')
        url=response.url()
        url='https://jobs.51job.com/all/co{}.html'.format(i)
        req=r.Request(url,headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'})#伪装
        data=r.urlopen(req).read().decode('gbk','ignore')
        selector = HTML(text=data)
        company_name='/html/body/div[2]/div[2]/div[2]/div/h1/@title'
        a1=str(selector.xpath(company_name)[0])
        company_situation='/html/body/div[2]/div[2]/div[2]/div/p/@title'
        a2=str(selector.xpath(company_situation)[0].strip())
        company_id='//*[@id="hidCOID"]/@value'
        a3=str(selector.xpath(company_id)[0])
        company_brief_introduction='/html/body/div[2]/div[2]/div[3]/div[1]/div/div/div[1]/div/text()'
        a4=str(selector.xpath(company_brief_introduction))
        company_address='/html/body/div[2]/div[2]/div[3]/div[2]/div/p[1]/text()'
        a5=str(selector.xpath(company_address)[1].strip())
        company_website='/html/body/div[2]/div[2]/div[3]/div[2]/div/p[2]/span[2]/text()'
        a6=str(selector.xpath(company_website))
        company_logo='/html/body/div[2]/div[2]/div[2]/div/img/@src'
        a7=str(selector.xpath(company_logo))
        company_position='//*[@id="hidTotal"]/@value'
        a8='公司职位数量：'+str(selector.xpath(company_position))
        company={'company_name':a1,'company_situation':a2,'company_id':a3,'company_brief_introduction':a4,'company_address':a5,'company_website':a6,'company_logo':a7,'company_positio':a8}
        f.write(str(company)+'\n')
        f.close()
    except Exception as err:
        print(err.args)
# Out:
# ("name 'response' is not defined",)

# %%
url='https://jobs.51job.com/all/co{}.html'.format(1686854)
req=r.Request(url,headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'})#伪装
data=r.urlopen(req).read().decode('gbk','ignore')
selector = HTML(text=data)
# company_name='/html/body/div[2]/div[2]/div[2]/div/h1/@title'
# print(str(selector.xpath(company_name)[0]))
# company_situation='/html/body/div[2]/div[2]/div[2]/div/p/@title'
# print(str(selector.xpath(company_situation)[0]))
company_id='//*[@id="hidCOID"]/@value'
# print(str(selector.xpath(company_id)[0]))
# company_brief_introduction='/html/body/div[2]/div[2]/div[3]/div[1]/div/div/div[1]/div/text()'
# print(str(selector.xpath(company_brief_introduction)))
# company_address='/html/body/div[2]/div[2]/div[3]/div[2]/div/p[1]/text()'
# print(str(selector.xpath(company_address)[1].strip()))
# company_website='/html/body/div[2]/div[2]/div[3]/div[2]/div/p[2]/span[2]/text()'
# print(str(selector.xpath(company_website)))
# company_logo='/html/body/div[2]/div[2]/div[2]/div/img/@src'
# print(str(selector.xpath(company_logo)))
# company_position='//*[@id="hidTotal"]/@value'
# print('公司职位数量：'+str(selector.xpath(company_position)))
prefix='//*[@id="joblistdata"]'
company_recruit=prefix+'//div[.]'
recruit_id=prefix+'//div[.]/p/a/@href'
# print(str(selector.xpath(recruit_id)[1].split('/')[-1].split('.')[-2]))
for i in range(len(selector.xpath(company_recruit))):
    #print(str(selector.xpath(company_recruit)[i][0].xpath('string(.)')))
    company_recruit_dir={
        '公司ID':str(selector.xpath(company_id)[0]),
        '职位ID':str(selector.xpath(recruit_id)[i].split('/')[-1].split('.')[-2]),
        '职位':str(selector.xpath(company_recruit)[i][0].xpath('string(.)')),
        '职位要求':str(selector.xpath(company_recruit)[i][1].xpath('string(.)')),
        '工作地点':str(selector.xpath(company_recruit)[i][2].xpath('string(.)')),
        '月薪':str(selector.xpath(company_recruit)[i][3].xpath('string(.)')),
        '发布时间':str(selector.xpath(company_recruit)[i][4].xpath('string(.)')),
    }
    print(company_recruit_dir)
# Out:
# {'公司ID': '1686854', '职位ID': '122287321', '职位': '硬件测试工程师', '职位要求': '2年经验 | 本科 | 招20人', '工作地点': '深圳', '月薪': '1-1.7万/月', '发布时间': '2020-05-22 09:45:41'}
# {'公司ID': '1686854', '职位ID': '122287171', '职位': '芯片测试工程师', '职位要求': '3-4年经验 | 本科 | 招10人', '工作地点': '上海', '月薪': '1-1.4万/月', '发布时间': '2020-05-22 09:44:22'}
# {'公司ID': '1686854', '职位ID': '122287420', '职位': 'C开发工程师', '职位要求': '2年经验 | 本科 | 招10人', '工作地点': '深圳', '月薪': '0.9-1.5万/月', '发布时间': '2020-05-22 09:21:36'}
# {'公司ID': '1686854', '职位ID': '122287274', '职位': 'Java开发工程师', '职位要求': '3-4年经验 | 本科 | 招5人', '工作地点': '深圳', '月薪': '1.2-1.8万/月', '发布时间': '2020-05-22 09:20:54'}
# {'公司ID': '1686854', '职位ID': '122287251', '职位': 'BA工程师', '职位要求': '3-4年经验 | 本科 | 招10人', '工作地点': '深圳', '月薪': '1.3-1.8万/月', '发布时间': '2020-05-22 09:20:38'}
# {'公司ID': '1686854', '职位ID': '122287218', '职位': '自动化测试工程师', '职位要求': '3-4年经验 | 本科 | 招13人', '工作地点': '上海', '月薪': '1-1.7万/月', '发布时间': '2020-05-22 09:20:26'}
# ...

# %%
from scrapy.selector import Selector
url='https://jobs.51job.com/all/co{}.html'.format(1686854)
req=r.Request(url,headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'})#伪装
data=r.urlopen(req).read().decode('gbk','ignore')
selector = HTML(text=data)
#url = "http://test"
data = {'pageno':'3',
       'hidTotal':'148',
       'type':'',
       'code':''}#post数据
res = requests.post(url=url,data=data)#post请求动态网页
print(res.text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
url='https://jobs.51job.com/all/co2265171.html#syzw'
req=r.Request(url,headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'})#伪装
data=r.urlopen(req).read().decode('gbk','ignore')
selector =Selector(text=data)
#url = "http://test"
data = {'pageno':'3',
       'hidTotal':'54',
       'type':'',
       'code':''}
res = requests.post(url=url,data=data)
print(res.text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
url='https://jobs.51job.com/all/co{}.html'.format(1686854)
req=r.Request(url,headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'})#伪装
data=r.urlopen(req).read().decode('gbk','ignore')
selector = HTML(text=data)
prefix='//*[@id="joblistdata"]'
company_recruit=prefix+'//div[.]'
recruit_id=prefix+'//div[.]/p/a/@href'
for i in range(len(selector.xpath(company_recruit))):
    company_recruit_dir={
        '公司ID':str(selector.xpath(company_id)[0]),
        '职位ID':str(selector.xpath(recruit_id)[i].split('/')[-1].split('.')[-2]),
        '职位':str(selector.xpath(company_recruit)[i][0].xpath('string(.)')),
        '职位要求':str(selector.xpath(company_recruit)[i][1].xpath('string(.)')),
        '工作地点':str(selector.xpath(company_recruit)[i][2].xpath('string(.)')),
        '月薪':str(selector.xpath(company_recruit)[i][3].xpath('string(.)')),
        '发布时间':str(selector.xpath(company_recruit)[i][4].xpath('string(.)')),
    }
    data = {'pageno':'3',
       'hidTotal':'54',
       'type':'',
       'code':''}
    res = requests.post(url=url,data=data)
    #print(res.text)
    print(company_recruit_dir)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...
